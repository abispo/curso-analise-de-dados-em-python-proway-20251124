# %% [markdown]
# # Notebook de Exercícios e Respostas – Estatística para Análise de Dados
#
# Este notebook contém **exercícios e respostas** para os três tópicos da Aula 1:
#
# 1. Amostragem (AAS, Sistemática, Estratificada)
# 2. Medidas de Centralidade
# 3. Medidas de Variabilidade
#
# Os exercícios utilizam **pandas, numpy, seaborn e matplotlib**.
#
# ---
#
# # ## 📘 PARTE 1 — Amostragem
#
# ## ### 📝 Exercício 1 — Amostragem Aleatória Simples
#
# Carregue o dataset *diamonds* do seaborn e:
#
# 1. Selecione apenas as colunas `carat`, `price` e `cut`.
# 2. Gere uma amostra aleatória simples com 300 linhas.
# 3. Calcule a média do preço na amostra e compare com a média do conjunto completo.
#
# ---
#
# ## ### 📝 Exercício 2 — Amostragem Sistemática
#
# Usando o mesmo dataset:
#
# 1. Ordene os dados pelo preço.
# 2. Selecione uma amostra sistemática pegando a cada 200 linhas.
# 3. Compare a média de `carat` da amostra com a média da população.
#
# ---
#
# ## ### 📝 Exercício 3 — Amostragem Estratificada
#
# Ainda com o dataset *diamonds*:
#
# 1. Considere `cut` como estrato.
# 2. Gere uma amostra estratificada pegando **5% de cada estrato**.
# 3. Compare a proporção de cada `cut` na amostra vs. população.
#
# ---

# %% [markdown]
# # ## 📘 PARTE 2 — Medidas de Centralidade
#
# ## ### 📝 Exercício 4
#
# Usando o dataset *tips* do seaborn:
#
# 1. Calcule média, mediana e moda da coluna `total_bill`.
# 2. Compare essas medidas e explique se a distribuição parece simétrica ou assimétrica.

# %% [markdown]
# # ## 📘 PARTE 3 — Medidas de Variabilidade
#
# ## ### 📝 Exercício 5
#
# Usando o dataset *wine_quality*:
#
# 1. Calcule amplitude, variância, desvio padrão de `alcohol`.
# 2. Calcule Q1, Q2, Q3 e IQR.
# 3. Identifique outliers usando o método do IQR.
# 4. Plote um boxplot.

# %% [markdown]
# # ## 🎯 Exercícios Extras (Simples)
#
# ### 📝 Exercício 6
#
# Crie uma lista de números e calcule:
#
# * média
# * mediana
# * amplitude
#
# ### 📝 Exercício 7
#
# Gere 1.000 valores usando `np.random.normal(0, 1)` e calcule:
#
# * variância
# * desvio padrão
# * verifique se o dp está próximo de 1.
